# %%
import regex as re
PAT = r"""'(?:[sdmt]|ll|ve|re)| ?\p{L}+| ?\p{N}+| ?[^\s\p{L}\p{N}]+|\s+(?!\S)|\s+"""    
x = re.finditer(PAT, "some text that i'll pre-tokenize")
for match in x:
    print(match.group(0))
# Out:
# some
#  text
#  that
#  i
# 'll
#  pre
# -
# tokenize
